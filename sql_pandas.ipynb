# %%
pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=a43d8a82d2e19fc0fda042181cbbce338026e3c38c3b9c3a6baeaeb039febced
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %% [markdown]
# **Diamonds dataset...**

# %%
from pandasql import sqldf
import pandas as pd
import seaborn as sns
dia=sns.load_dataset('diamonds')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
type((sqldf("select cut from dia where cut='Premium' or cut='Ideal'")))
# Out:
# pandas.core.frame.DataFrame

# %%
print(sqldf('''select * from dia where x>5 and y>5 and z>5'''))
# Out:
#       carat        cut color clarity  depth  table  price     x      y      z
# 0      1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 1      2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 2      2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 3      1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 4      2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...     ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 1452   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 1453   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 1454   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 1455   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 1456   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# [1457 rows x 10 columns]

# %%
print(sqldf('''select * from dia where cut='Premium' or cut="Ideal"'''))
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 3       0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 4       0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 35337   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 35338   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 35339   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 35340   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 35341   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]

# %%
dia[['cut','color']].head()
#extract 1st 5 rows
# Out:
#        cut color
# 0    Ideal     E
# 1  Premium     E
# 2     Good     E
# 3  Premium     I
# 4     Good     J

# %%
print(sqldf('''select * from dia where cut IN('Premium','Good','Fair')'''))
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 1       0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 2       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 3       0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 4       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 20302   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 20303   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 20304   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 20305   0.72     Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 20306   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [20307 rows x 10 columns]

# %%
print(dia.groupby('cut')['price'].max(),dia.groupby('cut')['price'].min(),dia.groupby('cut')['price'].count())
# Group the DataFrame 'dia' by the 'price' column and then select the 'price' column within each group. Finally, find the maximum value within each group.
# Out:
# cut
# Ideal        18806
# Premium      18823
# Very Good    18818
# Good         18788
# Fair         18574
# Name: price, dtype: int64 cut
# Ideal        326
# Premium      326
# Very Good    336
# Good         327
# Fair         337
# Name: price, dtype: int64 cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: price, dtype: int64

# %% [markdown]
# **Automobile dataset...**

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Automobile_data.csv")
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df1 = df[['company','price']][df.price==df['price'].max()]
df1
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
# Group the original DataFrame by 'company'
car = df.groupby('company')

# Get the group corresponding to 'toyota' (note the spelling)
df_toyota = car.get_group('toyota')
df_toyota
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
totalcar=car.size()
totalcar
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64

# %%
carprice=car['price'].max()
carprice
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
avgmileg=car['average-mileage'].mean()
avgmileg
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
sortcar=df.sort_values('price',ascending=False)
sortcar
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
# ..    ...            ...          ...         ...     ...         ...
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 22     31          isuzu        sedan        94.5   155.9         ohc
# 23     32          isuzu        sedan        94.5   155.9         ohc
# 47     63        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# ...

# %% [markdown]
# **occupation dataset...**

# %%
import pandas as pd
occ = pd.read_csv("/content/drive/MyDrive/occupation.csv")
occ
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 448      449   23      M      librarian    55021
# 449      450   35      F       educator    11758
# 450      451   16      M        student    48446
# 451      452   35      M  administrator    28018
# 452      453   18      M            NaN      NaN
#
# [453 rows x 5 columns]

# %%
avgocc=occ.groupby('occupation')['age'].mean()
avgocc
# Out:
# occupation
# administrator    37.431818
# artist           32.133333
# doctor           38.500000
# educator         41.422222
# engineer         38.060606
# entertainment    26.230769
# executive        37.000000
# healthcare       43.000000
# homemaker        32.250000
# lawyer           40.000000
# librarian        35.708333
# marketing        37.692308
# none             28.333333
# other            36.717949
# programmer       34.176471
# retired          62.800000
# salesman         35.166667
# scientist        36.466667
# student          22.111111
# technician       35.727273
# writer           34.222222
# Name: age, dtype: float64

# %%
maxocc,minocc=occ.groupby('occupation')['age'].max(),occ.groupby('occupation')['age'].min()
print(maxocc)
print("\n Min ages\n")
print(minocc)
# Out:
# occupation
# administrator    62
# artist           48
# doctor           51
# educator         61
# engineer         63
# entertainment    41
# executive        49
# healthcare       53
# homemaker        42
# lawyer           53
# librarian        54
# marketing        55
# none             55
# other            64
# programmer       53
# retired          68
# salesman         66
# scientist        45
# student          42
# technician       55
# writer           52
# Name: age, dtype: int64
#
#  Min ages
#
# occupation
# administrator    21
# artist           20
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           28
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          60
# salesman         21
# scientist        25
# student           7
# technician       24
# writer           21
# ...

# %%
out5 = occ.groupby(by=["occupation","gender"])[["age"]].mean().add_prefix("MeanOf_").reset_index()
out6 = out5.pivot(index="occupation",columns="gender",values="MeanOf_age")
out6
# Out:
# gender                 F          M
# occupation
# administrator  39.368421  35.960000
# artist         30.571429  33.500000
# doctor               NaN  38.500000
# educator       38.923077  42.437500
# engineer             NaN  38.060606
# entertainment        NaN  26.230769
# executive      44.000000  36.125000
# healthcare     40.333333  45.666667
# homemaker      32.250000        NaN
# lawyer         39.500000  40.142857
# librarian      35.500000  36.125000
# marketing      31.600000  41.500000
# none           45.000000  20.000000
# other          34.764706  38.227273
# programmer     33.000000  34.379310
# retired              NaN  62.800000
# salesman             NaN  35.166667
# scientist      26.000000  37.214286
# student        21.148148  22.523810
# technician           NaN  35.727273
# writer         39.600000  32.153846

# %%
ratioocc=ratioocc = occ[occ['gender'] == 'M'].groupby('occupation')['gender'].count()
ratioocc
# Out:
# occupation
# administrator    25
# artist            8
# doctor            4
# educator         32
# engineer         33
# entertainment    13
# executive        16
# healthcare        3
# lawyer            7
# librarian         8
# marketing         8
# none              4
# other            22
# programmer       29
# retired           5
# salesman          6
# scientist        14
# student          63
# technician       11
# writer           13
# Name: gender, dtype: int64
